# %%
"""

<외부 모듈(패키지, 라이브러리) 불려들여서 사용하기> 
 - 외부에 파일로 따로 클래스를 만들어 놓은 후
 - 사용할 파일에서 외부 파일을 불러들여서 사용하는 방법을 모듈 사용이라고 칭합니다.
 - 모듈을 불러들일 때 사용하는 명령
   : import 파일명
   : 또는 from 폴더 (파일)위치 import 클래스명

 - 주피터 노트북에서 외부에 생성한 .py 파일을 불러들일 때는
  -> 파일을 찾지 못하는 경우 : Kernel > Restart Kernel 한 후 합니다.

"""

# %%
### 지금 작성 중인 .ipynb 또는 .py과 동일한 위치에 존재하는 경우 처리
# - 외부 파일 불러들이기
import math_class

# %%
### 클래스 생성하기
# - import한 모듈명(파일명)으로 접근한 후, 파일 내부의 ㅋㄹ래스를 사용
# - inport하게되면, 해당 파일이 메모리에 적재되며, 주소가 부여됨
#   -> math_class는 파일에 접근하는 주소를 가지고 있음
# - math는 클래스 생성시 멤리 주소를 가지고 있음
math = math_class.Math(30,70)
math.aa, math.bb, math.getPlus()
# Out:
# (30, 70, 100)

# %% [markdown]
# ### 특정 폴더에 위치한 파일 불러들이기

# %%
### from 폴더명.파일명 import 클래스명
# 클래스명을 이용해서 바로 사용가능
from lib.math_class import Math

# %%
math = Math(20, 30)
math.aa, math.bb, math.getPlus()
# Out:
# (20, 30, 50)
